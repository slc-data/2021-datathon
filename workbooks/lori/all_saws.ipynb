# %% [markdown]
# # ALL SAWS DATA

# %% [markdown]
# - grabbing all data and putting into one dataframe to see usage by areas of san antonio

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read in all excels
df1 = pd.read_excel('s1.xlsx')

# %%
df2 = pd.read_excel('s2.xlsx')

# %%
df3 = pd.read_excel('s3.xlsx')

# %%
df1.head()
# Out:
#    Record # Prefix Service Location Suffix  ZIP Code 17-JAN 17-FEB 17-MAR  \
# 0         1    NaN              2ND     ST     78221   4489   5237   4489
# 1         2    NaN              2ND     ST     78221      0      0      0
# 2         3    NaN              2ND     ST     78221   9725  10473   7481
# 3         4    NaN              2ND     ST     78221   2992   4489    748
# 4         5    NaN              2ND     ST     78221   5237   5237   4489
#
#   17-APR 17-MAY  ... 20-MAR 20-APR 20-MAY 20-JUN 20-JUL 20-AUG 20-SEP 20-OCT  \
# 0   4489   5985  ...   2244   3740   3740   2992   5237   5237   2244   3740
# 1      0      0  ...   8229   6733   8977  10473  18702  11222  11222   8977
# 2   7481   9725  ...   6733   5237   6733   7481   8229   9725  10473   9725
# 3   1496    748  ...   2244   2244   2992   2992   2992   2992   2992   2992
# 4   5237   4489  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#   20-NOV 20-DEC
# 0   3740   2992
# 1   8229  11222
# 2   8977   7481
# 3   2244   2992
# 4    NaN    NaN
#
# [5 rows x 53 columns]

# %%
df2.head()
# Out:
#    Record # Prefix Service Location Suffix  ZIP Code 17-JAN 17-FEB 17-MAR  \
# 0    273591    NaN           ABACUS     DR     78224   2244   2244   1496
# 1    273592    NaN           ABACUS     DR     78224   2244   1496   2244
# 2    273593    NaN           ABACUS     DR     78224   6733   4489   3740
# 3    273594    NaN           ABACUS     DR     78224   5237   4489   5237
# 4    273595    NaN           ABACUS     DR     78224   5237   5237   5985
#
#   17-APR 17-MAY  ... 20-MAR 20-APR 20-MAY 20-JUN 20-JUL 20-AUG 20-SEP 20-OCT  \
# 0   2244   2244  ...   1496   2992   2244    748   3740   2244   1496   2244
# 1   2992   3740  ...   2244   2244   2244   2992   2992   1496   2244   3740
# 2   4489   7481  ...   2244   3740   5237   3740   4489   4489   8229   4489
# 3   4489   5237  ...  11222  13466  13466  14214  14962   8229   5985   6733
# 4   6733   5985  ...   4489   2992   3740   4489   2992      0      0    NaN
#
#   20-NOV 20-DEC
# 0   2244   2244
# 1   2244   2244
# 2   4489   3740
# 3      *    NaN
# 4    NaN    NaN
#
# [5 rows x 53 columns]

# %%
df3.head()
# Out:
#    Record # Prefix Service Location Suffix  ZIP Code 17-JAN 17-FEB 17-MAR  \
# 0    547625    NaN    ABADEER TRAIL    NaN     78253    NaN    NaN    NaN
# 1    547626    NaN    ABADEER TRAIL    NaN     78253    NaN    NaN    NaN
# 2    547627    NaN    ABADEER TRAIL    NaN     78253    NaN    NaN    NaN
# 3    547628    NaN    ABADEER TRAIL    NaN     78253    NaN    NaN    NaN
# 4    547629    NaN    ABADEER TRAIL    NaN     78253    NaN    NaN    NaN
#
#   17-APR 17-MAY  ... 20-MAR 20-APR 20-MAY 20-JUN 20-JUL 20-AUG 20-SEP 20-OCT  \
# 0    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#   20-NOV 20-DEC
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN
#
# [5 rows x 53 columns]

# %%
# check the shape before concatting
df1.shape
# Out:
# (273590, 53)

# %%
# check the shape before concatting
df2.shape
# Out:
# (274034, 53)

# %%
# check the shape before concatting
df3.shape
# Out:
# (248861, 53)

# %%
# Lets start putting them together
all_three = [df1, df2, df3]

# %%
# Now time to concat into one
all_saws = pd.concat(all_three)

# %%
# Check to make sure shape has 796485 rows and 53 columns
all_saws.shape
# Out:
# (796485, 53)

# %%
all_saws.head()
# Out:
#    Record # Prefix Service Location Suffix  ZIP Code 17-JAN 17-FEB 17-MAR  \
# 0         1    NaN              2ND     ST     78221   4489   5237   4489
# 1         2    NaN              2ND     ST     78221      0      0      0
# 2         3    NaN              2ND     ST     78221   9725  10473   7481
# 3         4    NaN              2ND     ST     78221   2992   4489    748
# 4         5    NaN              2ND     ST     78221   5237   5237   4489
#
#   17-APR 17-MAY  ... 20-MAR 20-APR 20-MAY 20-JUN 20-JUL 20-AUG 20-SEP 20-OCT  \
# 0   4489   5985  ...   2244   3740   3740   2992   5237   5237   2244   3740
# 1      0      0  ...   8229   6733   8977  10473  18702  11222  11222   8977
# 2   7481   9725  ...   6733   5237   6733   7481   8229   9725  10473   9725
# 3   1496    748  ...   2244   2244   2992   2992   2992   2992   2992   2992
# 4   5237   4489  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#   20-NOV 20-DEC
# 0   3740   2992
# 1   8229  11222
# 2   8977   7481
# 3   2244   2992
# 4    NaN    NaN
#
# [5 rows x 53 columns]

# %%
# turn into csv
#all_saws.to_csv('mega_saws.csv')

# %% [markdown]
# ## Now time to clean...

# %%
def fix_dates(all_saws):
    '''
    Function to fix year month column into
    datetime.  Adds arbitraty day. but keeps 
    the same month and year.  
    '''
    all_saws['datetime'] = '01-20' + all_saws['year_month']
    all_saws.datetime = pd.to_datetime(all_saws.datetime)
    return all_saws

def wrangle_saws():
    '''This function will drop unnecessary columns, 
    create a 'location' using data acquired from 
    other columns, and melt the data to make month year column'''
    # Reads the mega_saws csv
    all_saws = pd.read_csv('mega_saws.csv')
    # Removes NaN values from 'Prefix' and 'Suffix' column for concatenation in 'location'
    all_saws['Prefix'] = all_saws.Prefix.fillna(value = '')
    all_saws['Suffix'] = all_saws.Suffix.fillna(value = '')
    # Concatenating columns together for specific location
    all_saws['location'] = all_saws['Prefix'] + ' ' + all_saws['Service Location'] + ' ' + all_saws['Suffix']
    # Stripping any extra whitespace
    all_saws['location'] = all_saws.location.str.strip()
    all_saws = all_saws.drop(columns=['Unnamed: 0', 'Prefix', 'Suffix', 'Service Location'])
    #which vars should not be melted
    all_saws = all_saws.melt(id_vars=['Record #', 'ZIP Code', 'location'], 
    #var name:  the name of the column that will hold the names of the columns combined
              var_name='Month & Year', value_name='Gallons Consumed')
    #no longer want the index as record number because each record repeats 48 times
    #all_saws = all_saws.set_index('Record #')
    all_saws = all_saws.fillna(0)
    all_saws = all_saws.rename(columns={"ZIP Code": "zipcode", 'Month & Year':'year_month', 
                                'Gallons Consumed':'gallons_consumed'})
    return fix_dates(all_saws)

# %% [markdown]
# ### Current form issues:
# - the record numbers are no longer distinct, so now there is no way to tell which house consumed the most water

# %%
df = wrangle_saws()
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df.head()
# Out:
#    Record #  zipcode location year_month gallons_consumed   datetime
# 0         1    78221   2ND ST     17-JAN             4489 2017-01-01
# 1         2    78221   2ND ST     17-JAN                0 2017-01-01
# 2         3    78221   2ND ST     17-JAN             9725 2017-01-01
# 3         4    78221   2ND ST     17-JAN             2992 2017-01-01
# 4         5    78221   2ND ST     17-JAN             5237 2017-01-01

# %%
df.shape
# Out:
# (38231280, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38231280 entries, 0 to 38231279
# Data columns (total 6 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Record #          int64
#  1   zipcode           int64
#  2   location          object
#  3   year_month        object
#  4   gallons_consumed  object
#  5   datetime          datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 1.7+ GB

# %%
df.tail()
# Out:
#           Record #  zipcode  location year_month gallons_consumed   datetime
# 38231275    796481    78258   ZETA VW     20-DEC                * 2020-12-01
# 38231276    796482    78260  ZEUS CIR     20-DEC             2244 2020-12-01
# 38231277    796483    78260  ZEUS CIR     20-DEC            11222 2020-12-01
# 38231278    796484    78260  ZEUS CIR     20-DEC             5985 2020-12-01
# 38231279    796485    78260  ZEUS CIR     20-DEC             7481 2020-12-01

# %% [markdown]
# ## Initial Exploration

# %%
#explore in tableau
#df.to_csv('clean_saws.csv')

# %% [markdown]
# ### Tableau link:

# %% [markdown]
# - can't seem to upload to public without extracting data...stay tuned

# %% [markdown]
# ![Screen%20Shot%202021-07-29%20at%2011.46.18%20PM.png](attachment:Screen%20Shot%202021-07-29%20at%2011.46.18%20PM.png)

# %% [markdown]
# ## Exploration

# %% [markdown]
# ### Univariate Exploration

# %% [markdown]
# #### Zipcode

# %%
plt.figure(figsize=(16,8))
sns.countplot(data=df, x='zipcode')
plt.title('Observations per Zipcode')
plt.xlabel('Zipcodes')
plt.ylabel('Observations')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Observations per Zipcode
# - If we divide the amount of observations by 48, we can get the amount of residencies on each street, since each record number has 4 years worth of consumption data.
# - More observations means more houses on that street, so we can see the zipz that were consuming the most water also have the most observations, except for water guzzler 78258:  78245, 78254, 78253

# %% [markdown]
# #### Gallons

# %% [markdown]
# - gallons is actually an object type bc of the *
# - going to need to change the data type to int if I want to do any aggregate functions
# - probs just going to fill the asterisk with zero, because it represents that the house was vacant or was a new home

# %%
#quick glance
df.head()
# Out:
#    Record #  zipcode location year_month gallons_consumed   datetime
# 0         1    78221   2ND ST     17-JAN             4489 2017-01-01
# 1         2    78221   2ND ST     17-JAN                0 2017-01-01
# 2         3    78221   2ND ST     17-JAN             9725 2017-01-01
# 3         4    78221   2ND ST     17-JAN             2992 2017-01-01
# 4         5    78221   2ND ST     17-JAN             5237 2017-01-01

# %%
#quick look at how many houses with 0 consumption
df.gallons_consumed.value_counts()
# Out:
# 0        15443078
# 3740      2136767
# 2992      2086872
# 4489      2005018
# 2244      1817132
#            ...
# 14003           1
# 19499           1
# 22398           1
# 15203           1
# 36340           1
# Name: gallons_consumed, Length: 2763, dtype: int64

# %%
#new houses or vancant houses have *
no_consumption = df[df.gallons_consumed == '*']

# %%
#quick peek
no_consumption.head()
# Out:
#       Record #  zipcode      location year_month gallons_consumed   datetime
# 752        753    78207         ADAES     17-JAN                * 2017-01-01
# 850        851    78210      ADAMS ST     17-JAN                * 2017-01-01
# 1504      1505    78109  AFTON CANYON     17-JAN                * 2017-01-01
# 1640      1641    78212      AGNES DR     17-JAN                * 2017-01-01
# 1749      1750    78212   ALAMEDA CIR     17-JAN                * 2017-01-01

# %%
#how many observations with no consumption
len(no_consumption)
# Out:
# 103609

# %%
#replace * with 0 in no consumption dataset before trying on main dataset

no_consumption.replace({'gallons_consumed': {'*': '0'}})
# Out:
#           Record #  zipcode      location year_month gallons_consumed  \
# 752            753    78207         ADAES     17-JAN                0
# 850            851    78210      ADAMS ST     17-JAN                0
# 1504          1505    78109  AFTON CANYON     17-JAN                0
# 1640          1641    78212      AGNES DR     17-JAN                0
# 1749          1750    78212   ALAMEDA CIR     17-JAN                0
# ...            ...      ...           ...        ...              ...
# 38229476    794682    78251      WOODLINE     20-DEC                0
# 38230061    795267    78250     WOODTRAIL     20-DEC                0
# 38230974    796180    78253      YEGUA LN     20-DEC                0
# 38231264    796470    78258      ZETA CIR     20-DEC                0
# 38231275    796481    78258       ZETA VW     20-DEC                0
#
#            datetime
# 752      2017-01-01
# 850      2017-01-01
# 1504     2017-01-01
# 1640     2017-01-01
# 1749     2017-01-01
# ...             ...
# 38229476 2020-12-01
# 38230061 2020-12-01
# 38230974 2020-12-01
# 38231264 2020-12-01
# 38231275 2020-12-01
#
# [103609 rows x 6 columns]

# %%
# function to replace '*' with 0 in main dataset and change object type to int
df.replace({'gallons_consumed': {'*': '0'}}, inplace=True)

# %%
#check to ensure * are replaced
df[df.gallons_consumed == '*']
# Out:
# Empty DataFrame
# Columns: [Record #, zipcode, location, year_month, gallons_consumed, datetime]
# Index: []

# %%
#check datatypes before changing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38231280 entries, 0 to 38231279
# Data columns (total 6 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Record #          int64
#  1   zipcode           int64
#  2   location          object
#  3   year_month        object
#  4   gallons_consumed  object
#  5   datetime          datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 1.7+ GB

# %%
#now lets change the objects to ints
df["gallons_consumed"] = df["gallons_consumed"].astype(str).astype(int)

# %%
#check to ensure change took place
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38231280 entries, 0 to 38231279
# Data columns (total 6 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Record #          int64
#  1   zipcode           int64
#  2   location          object
#  3   year_month        object
#  4   gallons_consumed  int64
#  5   datetime          datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 1.7+ GB

# %% [markdown]
# - yay now back to exploring consumption

# %%
#take a look at basic aggregations
df.groupby('zipcode').gallons_consumed.agg(['min', 'mean', 'max'])
# Out:
#          min         mean     max
# zipcode
# 78006      0  6650.688022  612694
# 78015      0  3936.917483  248369
# 78023      0  5923.641383  248369
# 78065      0  4819.493566  198995
# 78069      0  3705.498023  124933
# ...      ...          ...     ...
# 78260      0  5293.203952  247621
# 78261      0  4493.170021  243132
# 78263      0  5804.960990  185529
# 78264      0  4825.330033  246125
# 78266      0  3073.256459  183284
#
# [66 rows x 3 columns]

# %%
#make some time datasets
df['year'] = df.datetime.dt.year
df['month'] = df.datetime.dt.month
df.head()
# Out:
#    Record #  zipcode location year_month  gallons_consumed   datetime  year  \
# 0         1    78221   2ND ST     17-JAN              4489 2017-01-01  2017
# 1         2    78221   2ND ST     17-JAN                 0 2017-01-01  2017
# 2         3    78221   2ND ST     17-JAN              9725 2017-01-01  2017
# 3         4    78221   2ND ST     17-JAN              2992 2017-01-01  2017
# 4         5    78221   2ND ST     17-JAN              5237 2017-01-01  2017
#
#    month
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
#make sure dataset is sorted by datetime field
df = df.set_index('datetime').sort_index()

# %%
df.head()
# Out:
#             Record #  zipcode location year_month  gallons_consumed  year  \
# datetime
# 2017-01-01         1    78221   2ND ST     17-JAN              4489  2017
# 2017-01-01         2    78221   2ND ST     17-JAN                 0  2017
# 2017-01-01         3    78221   2ND ST     17-JAN              9725  2017
# 2017-01-01         4    78221   2ND ST     17-JAN              2992  2017
# 2017-01-01         5    78221   2ND ST     17-JAN              5237  2017
#
#             month
# datetime
# 2017-01-01      1
# 2017-01-01      1
# 2017-01-01      1
# 2017-01-01      1
# 2017-01-01      1

# %%
#begining and end of time
df.index.min(), df.index.max()
# Out:
# (Timestamp('2017-01-01 00:00:00'), Timestamp('2020-12-01 00:00:00'))

# %%
#gallons consumed per year every 3 months
plt.figure(figsize=(16,8))
df.gallons_consumed.resample('M').mean().plot(marker='o')
plt.title('Gallons Consumed Every Month')
plt.xlabel('Year')
plt.ylabel('Gallons Consumed')
plt.xticks(rotation=45)
plt.show()

# %%
#gallons consumed per year every 3 months
plt.figure(figsize=(16,8))
df.gallons_consumed.resample('3M').mean().plot(marker='o')
plt.title('Gallons Consumed Every 3 Months')
plt.xlabel('Year')
plt.ylabel('Gallons Consumed')
plt.xticks(rotation=45)
plt.show()

# %%
#gallons consumed per year every 6 months
plt.figure(figsize=(16,8))
df.gallons_consumed.resample('6M').mean().plot(marker='o')
plt.title('Gallons Consumed Every 6 Months')
plt.xlabel('Year')
plt.ylabel('Gallons Consumed')
plt.xticks(rotation=45)
plt.show()

# %%
#store the target we are exploring
y = df.gallons_consumed
y.head()
# Out:
# datetime
# 2017-01-01    4489
# 2017-01-01       0
# 2017-01-01    9725
# 2017-01-01    2992
# 2017-01-01    5237
# Name: gallons_consumed, dtype: int64

# %%
y.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.figure(figsize=(16,8))
ax = y.groupby(y.index.month).mean().plot.bar(width=.9, ec='black')
plt.xticks(rotation=0)
ax.set(title='Average Consumption by Month', xlabel='Month', ylabel='Gallons Consumed')
# Out:
# [Text(0.5, 1.0, 'Average Consumption by Month'),
#  Text(0.5, 0, 'Month'),
#  Text(0, 0.5, 'Gallons Consumed')]

# %%
df.head()
# Out:
#             Record #  zipcode location year_month  gallons_consumed  year  \
# datetime
# 2017-01-01         1    78221   2ND ST     17-JAN              4489  2017
# 2017-01-01         2    78221   2ND ST     17-JAN                 0  2017
# 2017-01-01         3    78221   2ND ST     17-JAN              9725  2017
# 2017-01-01         4    78221   2ND ST     17-JAN              2992  2017
# 2017-01-01         5    78221   2ND ST     17-JAN              5237  2017
#
#             month
# datetime
# 2017-01-01      1
# 2017-01-01      1
# 2017-01-01      1
# 2017-01-01      1
# 2017-01-01      1

# %%
plt.figure(figsize=(16,8))

y.resample('M').mean().diff().plot(title='Average month-to-month change in consumption')
# Out:
# <AxesSubplot:title={'center':'Average month-to-month change in consumption'}, xlabel='datetime'>

# %%
plt.figure(figsize=(16,8))
y.groupby([y.index.year, y.index.month]).mean().unstack(0).plot(title='Seasonal Plot')
# Out:
# <AxesSubplot:title={'center':'Seasonal Plot'}, xlabel='datetime'>

# %% [markdown]
# ## Forcasting

# %% [markdown]
# - forecasting 2021 consumption through tableau

# %% [markdown]
# ![Screen%20Shot%202021-08-03%20at%2010.18.14%20PM.png](attachment:Screen%20Shot%202021-08-03%20at%2010.18.14%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202021-08-03%20at%2010.20.08%20PM.png](attachment:Screen%20Shot%202021-08-03%20at%2010.20.08%20PM.png)
