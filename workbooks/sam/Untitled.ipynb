# %%
import pandas as pd

# %%
pd.read_csv('COSA Downtown Air Quality.csv')
# Out:
#                   DateTime         Sensor_id Vendor               SensorModel  \
# 0      2021-05-16T00:01:26  64d7e4dbde37ccb5    ATT  AQM-01-00-01-00-01-00-GY
# 1      2021-05-16T00:04:26  64d7e4dbde37ccb5    ATT  AQM-01-00-01-00-01-00-GY
# 2      2021-05-16T00:07:26  64d7e4dbde37ccb5    ATT  AQM-01-00-01-00-01-00-GY
# 3      2021-05-16T00:10:26  64d7e4dbde37ccb5    ATT  AQM-01-00-01-00-01-00-GY
# 4      2021-05-16T00:13:26  64d7e4dbde37ccb5    ATT  AQM-01-00-01-00-01-00-GY
# ...                    ...               ...    ...                       ...
# 23374  2021-05-01T23:35:00             70456  ITRON                 ClimaCell
# 23375  2021-05-01T23:40:00             70456  ITRON                 ClimaCell
# 23376  2021-05-01T23:45:00             70456  ITRON                 ClimaCell
# 23377  2021-05-01T23:50:00             70456  ITRON                 ClimaCell
# 23378  2021-05-01T23:55:00             70456  ITRON                 ClimaCell
#
# ...

# %%
pd.read_csv('med_center_saws copy.csv', encoding = "utf-8")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-e1f25822663c> in <module>
# ----> 1 pd.read_csv('med_center_saws copy.csv', encoding = "utf-8")
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...
